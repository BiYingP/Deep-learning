# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]
print("Input shape: {}".format(input_shape))
# Out:
# Input shape: [63]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model =  keras.Sequential([
    layers.BatchNormalization(),
    layers.Dense(256, activation='relu', input_shape=[63]),  
    layers.BatchNormalization(),
    layers.Dropout(rate=0.3),
    layers.Dense(256, activation='relu'),  
    layers.BatchNormalization(),
    layers.Dropout(rate=0.3),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728174323.571608     172 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 175/175 [==============================] - 6s 7ms/step - loss: 0.4875 - binary_accuracy: 0.7696 - val_loss: 0.4324 - val_binary_accuracy: 0.8048
# Epoch 2/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.4264 - binary_accuracy: 0.7991 - val_loss: 0.4034 - val_binary_accuracy: 0.8146
# Epoch 3/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.4108 - binary_accuracy: 0.8073 - val_loss: 0.3918 - val_binary_accuracy: 0.8185
# Epoch 4/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.4031 - binary_accuracy: 0.8118 - val_loss: 0.3903 - val_binary_accuracy: 0.8218
# Epoch 5/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3983 - binary_accuracy: 0.8143 - val_loss: 0.3862 - val_binary_accuracy: 0.8226
# Epoch 6/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3931 - binary_accuracy: 0.8173 - val_loss: 0.3820 - val_binary_accuracy: 0.8230
# Epoch 7/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3895 - binary_accuracy: 0.8182 - val_loss: 0.3809 - val_binary_accuracy: 0.8262
# Epoch 8/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3862 - binary_accuracy: 0.8203 - val_loss: 0.3789 - val_binary_accuracy: 0.8252
# Epoch 9/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3827 - binary_accuracy: 0.8223 - val_loss: 0.3754 - val_binary_accuracy: 0.8287
# Epoch 10/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3813 - binary_accuracy: 0.8229 - val_loss: 0.3748 - val_binary_accuracy: 0.8267
# Epoch 11/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3778 - binary_accuracy: 0.8240 - val_loss: 0.3747 - val_binary_accuracy: 0.8283
# Epoch 12/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3753 - binary_accuracy: 0.8273 - val_loss: 0.3707 - val_binary_accuracy: 0.8317
# Epoch 13/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3736 - binary_accuracy: 0.8271 - val_loss: 0.3694 - val_binary_accuracy: 0.8333
# Epoch 14/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3713 - binary_accuracy: 0.8289 - val_loss: 0.3681 - val_binary_accuracy: 0.8319
# Epoch 15/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3696 - binary_accuracy: 0.8292 - val_loss: 0.3694 - val_binary_accuracy: 0.8310
# Epoch 16/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3663 - binary_accuracy: 0.8307 - val_loss: 0.3647 - val_binary_accuracy: 0.8346
# Epoch 17/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3633 - binary_accuracy: 0.8326 - val_loss: 0.3627 - val_binary_accuracy: 0.8338
# Epoch 18/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3646 - binary_accuracy: 0.8322 - val_loss: 0.3620 - val_binary_accuracy: 0.8356
# Epoch 19/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3609 - binary_accuracy: 0.8334 - val_loss: 0.3612 - val_binary_accuracy: 0.8346
# Epoch 20/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3605 - binary_accuracy: 0.8337 - val_loss: 0.3629 - val_binary_accuracy: 0.8331
# Epoch 21/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3574 - binary_accuracy: 0.8352 - val_loss: 0.3589 - val_binary_accuracy: 0.8368
# Epoch 22/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3587 - binary_accuracy: 0.8339 - val_loss: 0.3594 - val_binary_accuracy: 0.8356
# Epoch 23/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3546 - binary_accuracy: 0.8364 - val_loss: 0.3613 - val_binary_accuracy: 0.8346
# Epoch 24/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3558 - binary_accuracy: 0.8353 - val_loss: 0.3565 - val_binary_accuracy: 0.8381
# Epoch 25/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3539 - binary_accuracy: 0.8360 - val_loss: 0.3584 - val_binary_accuracy: 0.8354
# Epoch 26/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3521 - binary_accuracy: 0.8372 - val_loss: 0.3546 - val_binary_accuracy: 0.8391
# Epoch 27/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3506 - binary_accuracy: 0.8380 - val_loss: 0.3570 - val_binary_accuracy: 0.8367
# Epoch 28/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3495 - binary_accuracy: 0.8388 - val_loss: 0.3534 - val_binary_accuracy: 0.8382
# Epoch 29/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3485 - binary_accuracy: 0.8392 - val_loss: 0.3557 - val_binary_accuracy: 0.8368
# Epoch 30/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3487 - binary_accuracy: 0.8382 - val_loss: 0.3553 - val_binary_accuracy: 0.8379
# Epoch 31/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3474 - binary_accuracy: 0.8400 - val_loss: 0.3543 - val_binary_accuracy: 0.8383
# Epoch 32/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3453 - binary_accuracy: 0.8414 - val_loss: 0.3534 - val_binary_accuracy: 0.8396
# Epoch 33/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3450 - binary_accuracy: 0.8407 - val_loss: 0.3518 - val_binary_accuracy: 0.8399
# Epoch 34/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3430 - binary_accuracy: 0.8419 - val_loss: 0.3508 - val_binary_accuracy: 0.8394
# Epoch 35/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3417 - binary_accuracy: 0.8417 - val_loss: 0.3531 - val_binary_accuracy: 0.8382
# Epoch 36/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3430 - binary_accuracy: 0.8413 - val_loss: 0.3506 - val_binary_accuracy: 0.8407
# Epoch 37/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3416 - binary_accuracy: 0.8415 - val_loss: 0.3528 - val_binary_accuracy: 0.8396
# Epoch 38/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3401 - binary_accuracy: 0.8429 - val_loss: 0.3486 - val_binary_accuracy: 0.8417
# Epoch 39/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3407 - binary_accuracy: 0.8426 - val_loss: 0.3504 - val_binary_accuracy: 0.8413
# Epoch 40/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3387 - binary_accuracy: 0.8433 - val_loss: 0.3504 - val_binary_accuracy: 0.8391
# Epoch 41/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3394 - binary_accuracy: 0.8435 - val_loss: 0.3495 - val_binary_accuracy: 0.8404
# Epoch 42/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3381 - binary_accuracy: 0.8419 - val_loss: 0.3509 - val_binary_accuracy: 0.8407
# Epoch 43/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3366 - binary_accuracy: 0.8450 - val_loss: 0.3500 - val_binary_accuracy: 0.8428
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
